# %% [markdown]
# <a href="https://colab.research.google.com/github/MarinhoDevTi/inteligenciaArtificial/blob/main/praticAula02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    "name": ["Avery Bradley", "Jonh Holland", "Jonas Jerebko", "Jordan Mickey", "Terry Rozier", "Jared Sullinger", "Evan Turner"],
    "Team": ["Boston Celtics"] * 7,
    "number": [0, 30, 16, 60, 32, 90, 48],
    "position": ["PG", "SG", "PF", "PF", "PG", "C", "SG"],
    "age": [25.0, 26.0, 27.0, 28.0, 29.0, 30.0, 31.0]
}

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
df = pd.DataFrame(data)
df
# Out:
#               name            Team  number position   age
# 0    Avery Bradley  Boston Celtics       0       PG  25.0
# 1     Jonh Holland  Boston Celtics      30       SG  26.0
# 2    Jonas Jerebko  Boston Celtics      16       PF  27.0
# 3    Jordan Mickey  Boston Celtics      60       PF  28.0
# 4     Terry Rozier  Boston Celtics      32       PG  29.0
# 5  Jared Sullinger  Boston Celtics      90        C  30.0
# 6      Evan Turner  Boston Celtics      48       SG  31.0

# %%
df.loc[[2,0]]
# Out:
#             name            Team  number position   age
# 2  Jonas Jerebko  Boston Celtics      16       PF  27.0
# 0  Avery Bradley  Boston Celtics       0       PG  25.0

# %%
df[["name", "Team"]]
# Out:
#               name            Team
# 0    Avery Bradley  Boston Celtics
# 1     Jonh Holland  Boston Celtics
# 2    Jonas Jerebko  Boston Celtics
# 3    Jordan Mickey  Boston Celtics
# 4     Terry Rozier  Boston Celtics
# 5  Jared Sullinger  Boston Celtics
# 6      Evan Turner  Boston Celtics

# %%
df.loc[0] ["name"]
# Out:
# 'Avery Bradley'

# %%
df["name"].loc[0]
# Out:
# 'Avery Bradley'

# %%
df = pd.read_csv("data.csv")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
